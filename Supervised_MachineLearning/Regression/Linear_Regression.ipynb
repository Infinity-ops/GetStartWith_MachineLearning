# %% [markdown]
# ## Step-1 Dataset
# Reading the datapoints X and Y from the github link

# %%
import pandas as pd
url = 'https://raw.githubusercontent.com/Narmada-Ambigapathy/GetStartWith_MachineLearning/master/Datasets/Salary_Data.csv'
df = pd.read_csv(url, names = "a,b")
x = df["a"]
y = df["b"]

# %% [markdown]
# ## Find Slope and Intercept

# %%
slope, intercept = Linear_Regression.best_fit_slope_and_intercept(x,y)

# %% [markdown]
# ## Prediction

# %%
y_pred = Linear_Regression.predict(x, slope, intercept)

# %% [markdown]
# ## Find the loss

# %%
loss = Linear_Regression.sqr_loss(y, y_pred)

# %% [markdown]
# ## Visualization

# %%
Linear_Regression.plot(x,y,y_pred)
Linear_Regression.loss_plot(y_pred, loss)

# %% [markdown]
# ## Error updation

# %%
new_slope, new_intercept = Linear_Regression.gradient_descent_iter(slope, intercept,x, y,loss,1000)

# %% [markdown]
# ## Prediction by updating error

# %%
y_pred2 = Linear_Regression.predict(x, new_slope, new_intercept)

# %% [markdown]
# ## Visualizationfor new prediction

# %%
Linear_Regression.plot(x,y,y_pred2)

# %%
import matplotlib.pyplot as plt

class Linear_Regression:
    
    def best_fit_slope_and_intercept(x,y):
        num_a = ((mean.find_sum(x))*mean.find_sum(y)) - (mean.find_mul_sum(x,y))
        den_a = ((mean.find_sum(x))**2) - ((mean.find_mul_sum(x,x)))
        a = num_a/den_a
        b = mean.find_sum(y) - (a * mean.find_sum(x))
        return a,b
    
    def predict(x, a, b):
        y_pred = []
        for i in x:
            y_pred.append(a * i + b)
        return y_pred

    def sqr_loss(y, y_pred):
        loss = []
        for i in range(len(y)):
            loss.append(((y_pred[i] - y[i])**2)/len(y))
        return loss
    
    def mse_loss(y, y_pred):
        loss = []
        for i in range(len(y)):
            loss.append(np.mean((y_pred[i] - y[i])**2))
        return loss

    def rmse_loss(y, y_pred):
        loss = []
        for i in range(len(y)):
            loss.append(np.sqrt(np.mean((y_pred[i] - y[i])**2)))
        return loss

    def mae_loss(y, y_pred):
        loss = []
        for i in range(len(y)):
            loss.append(np.mean(y_pred[i] - y[i]))
        return loss
    
    def batch_gradient_descent1(slope, intercept,x, loss):
        learning_rate = 0.0001
        for i in range(len(x)):
            new_slope = slope + (loss[i] * x[i] * learning_rate)
            new_intercept = intercept  + (loss[i] * learning_rate)
        return new_slope, new_intercept
    
    def stochastic_gradient_descent2(slope, intercept,x,y, loss):
        slope_gradient = 0
        intercept_gradient = 0
        learning_rate = 0.0001
        N = len(x)
        for i in range(len(x)):
            slope_gradient += -(2/N) * x[i] *(y[i] - ((slope * x[i]) + intercept))
            intercept_gradient += -(2/N)  * (y[i] - ((slope * x[i]) + intercept))
        new_slope = slope - (slope_gradient * learning_rate)
        new_intercept = intercept  - (intercept_gradient * learning_rate)
        return new_slope, new_intercept


    def gradient_descent_iter(slope, intercept, x,y, loss, num_iterations):
        new_intercept = intercept
        new_slope = slope
        for i in range(num_iterations):
            new_slope, new_intercept = Linear_Regression.stochastic_gradient_descent2(slope, intercept, x,y, loss)
        return [new_slope, new_intercept]
    
    def plot(x,y,y_pred):
        plt.scatter(x, y, color = 'red')
        plt.plot(x, y_pred, color = 'blue')
        plt.title('Ownregression')
        plt.xlabel('X')
        plt.ylabel('Y')
        plt.show()
        
    def loss_plot(y_pred, loss):
        plt.plot(y_pred, loss,'b-', label = "Loss plot")
        plt.xlabel('Predicted value')
        plt.ylabel('Loss values')

# %%
class mean:
    
    def find_sum(l):
        res = 0
        for i in l:
            res += i
        return res/len(l)
    
    def find_mul_sum(l1, l2):
        res = 0
        for i in range(len(l1)):
            res += (l1[i]*l2[i])
        return res/len(l1)

# %%
print(y,y_pred, y_pred2)
# Out:
# 0      39343.0
# 1      46205.0
# 2      37731.0
# 3      43525.0
# 4      39891.0
# 5      56642.0
# 6      60150.0
# 7      54445.0
# 8      64445.0
# 9      57189.0
# 10     63218.0
# 11     55794.0
# 12     56957.0
# 13     57081.0
# 14     61111.0
# 15     67938.0
# 16     66029.0
# 17     83088.0
# 18     81363.0
# 19     93940.0
# 20     91738.0
# 21     98273.0
# 22    101302.0
# 23    113812.0
# 24    109431.0
# 25    105582.0
# 26    116969.0
# 27    112635.0
# 28    122391.0
# 29    121872.0
# ...
